# %%
import numpy as np
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,10,100)
y = np.sin(x)

# %% [markdown]
# To run GUI event loop

# %%
plt.ion()

# %%
figure, ax = plt.subplots(figsize=(10,8))
line1, = ax.plot(x,y)
plt.title("Aptitud", fontsize =20)
plt.xlabel("Generación")
plt.ylabel("Valor en función objetivo")
for _ in range(50):
    #creating new Y values
    new_y = np.sin(x-0.5*_)
    
    #updating data values
    line1.set_xdata(x)
    line1.set_ydata(new_y)
    
    #drawing updated values
    figure.canvas.draw()
    
    
    #this will run the GUI event
    # loop until all UI events
    # currently waiting hace been processed
    figure.canvas.flush_events()
    time.sleep(0.1)

# %%
type(line1)

elems = ax.plot(x,y)

# %%
x = [random.random()]
# Out:
# array([0.07561667])

# %%
import numpy as np
def rastring_plot(x,y):
    A=10
    return A*2 + (x**2-A*np.cos(2*np.pi*x))+y**2-A*np.cos(2*np.pi*y)

# %%
rastring_plot(x)
# Out:
# 1046.0269360269358

# %% [markdown]
# ## Función de Rastring
# $$ f(\mathbf{x}) = A n + \sum_{i=1}^n \left[x_i^2 - A\cos(2 \pi x_i)\right]$$
# $$ \text{where: }  A=10 $$
#
# **Mínimo global**
# $ f(0, \dots, 0) = 0f(0, \dots, 0) = 0$

# %%
import matplotlib.pyplot as plt
n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
X,Y = np.meshgrid(x, y)
f= rastring_plot

plt.axes([0.025, 0.025, 0.95, 0.95])

plt.contourf(X, Y, f(X, Y), 8, alpha=.75, cmap=plt.cm.hot)
C = plt.contour(X, Y, f(X, Y), 8, colors='black', linewidth=.5)
plt.clabel(C, inline=1, fontsize=10)

plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# /tmp/ipykernel_13175/2718855592.py:11: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   C = plt.contour(X, Y, f(X, Y), 8, colors='black', linewidth=.5)

# %%
np.cos(2*np.pi*x)
# Out:
# array([ 1.        ,  0.9679487 ,  0.87384938,  0.72373404,  0.52722547,
#         0.29692038,  0.04758192, -0.20480667, -0.44406661, -0.65486073,
#        -0.82367658, -0.93969262, -0.99547192, -0.98743889, -0.91610846,
#        -0.78605309, -0.60560969, -0.38634513, -0.14231484,  0.1108382 ,
#         0.35688622,  0.58005691,  0.76604444,  0.90292654,  0.9819287 ,
#         0.99798668,  0.95007112,  0.84125353,  0.67850941,  0.47227107,
#         0.23575894, -0.01586596, -0.26647381, -0.5       , -0.70147489,
#        -0.85798341, -0.95949297, -0.99949654, -0.97542979, -0.88883545,
#        -0.74526445, -0.55392006, -0.32706796, -0.07924996,  0.17364818,
#         0.41541501,  0.63055267,  0.80527026,  0.92836793,  0.99195481,
#         0.99195481,  0.92836793,  0.80527026,  0.63055267,  0.41541501,
#         0.17364818, -0.07924996, -0.32706796, -0.55392006, -0.74526445,
#        -0.88883545, -0.97542979, -0.99949654, -0.95949297, -0.85798341,
#        -0.70147489, -0.5       , -0.26647381, -0.01586596,  0.23575894,
#         0.47227107,  0.67850941,  0.84125353,  0.95007112,  0.99798668,
#         0.9819287 ,  0.90292654,  0.76604444,  0.58005691,  0.35688622,
#         0.1108382 , -0.14231484, -0.38634513, -0.60560969, -0.78605309,
#        -0.91610846, -0.98743889, -0.99547192, -0.93969262, -0.82367658,
#        -0.65486073, -0.44406661, -0.20480667,  0.04758192,  0.29692038,
#         0.52722547,  0.72373404,  0.87384938,  0.9679487 ,  1.        ])
